# %%
import pandas as pd

# %%
df = pd.read_csv('Book1.csv')
df.head()
# Out:
#   jobs_id_list = ;"jobs_id_list = [{name John        job: eng     age: 35  \
# 0                                 {name: Nate         job:eng    'age: 50
# 1                                 {name: Yuna        job: eng     age: 45
# 2                          {'name': 'Abraham'   'job': ""dr""   'age': 27
# 3                            {'name': 'Brian'   'job': ""dr""   'age': 30
# 4                            {'name': 'Janny'   'job': ""dr""   'age': 39
#
#             id_n:76}  Unnamed: 4
# 0   'id_n':""None""}         NaN
# 1           id_n:95}         NaN
# 2     'id_n':""89""}         NaN
# 3   'id_n':""None""}         NaN
# 4     'id_n':""67""}         NaN

# %%
df. shape
# Out:
# (14, 5)

# %%
df.isnull()
# Out:
#     jobs_id_list = ;"jobs_id_list = [{name John  job: eng   age: 35  \
# 0                                         False     False     False
# 1                                         False     False     False
# 2                                         False     False     False
# 3                                         False     False     False
# 4                                         False     False     False
# 5                                         False     False     False
# 6                                         False     False     False
# 7                                         False      True      True
# 8                                         False      True      True
# 9                                         False      True      True
# 10                                        False      True      True
# 11                                        False      True      True
# 12                                        False      True      True
# 13                                        False      True      True
#
#      id_n:76}  Unnamed: 4
# 0       False        True
# 1       False        True
# 2       False        True
# 3       False        True
# 4       False        True
# 5       False        True
# 6       False        True
# 7        True        True
# 8        True        True
# 9        True        True
# 10       True        True
# 11       True        True
# 12       True        True
# 13       True        True

# %%
df.isnull().sum()
# Out:
# jobs_id_list = ;"jobs_id_list = [{name John     0
# job: eng                                        7
#  age: 35                                        7
#  id_n:76}                                       7
# Unnamed: 4                                     14
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 35

# %%
df2 = df.fillna(value=0)
df2
# Out:
#           jobs_id_list = ;"jobs_id_list = [{name John         job: eng  \
# 0                                         {name: Nate          job:eng
# 1                                         {name: Yuna         job: eng
# 2                                  {'name': 'Abraham'    'job': ""dr""
# 3                                    {'name': 'Brian'    'job': ""dr""
# 4                                    {'name': 'Janny'    'job': ""dr""
# 5                                     {'name': 'Nate'    'job': ""dr""
# 6                                     {'name': 'John'   'job': ""eng""
# 7                                                   ;                0
# 8                                                   ;                0
# 9                   {'name': 'Abraham', 'job': "dr...                0
# 10                  {'name': 'Brian', 'job': "dr",...                0
# 11                  {'name': 'Janny', 'job': "dr",...                0
# 12                  {'name': 'Nate', 'job': "dr", ...                0
# 13                  {'name': 'John', 'job': "eng",...                0
#
#          age: 35           id_n:76}  Unnamed: 4
# 0       'age: 50   'id_n':""None""}         0.0
# 1        age: 45           id_n:95}         0.0
# 2      'age': 27     'id_n':""89""}         0.0
# 3      'age': 30   'id_n':""None""}         0.0
# 4      'age': 39     'id_n':""67""}         0.0
# 5    'age': None     'id_n':""82""}         0.0
# 6    'age': None    'id_n':""69""}"         0.0
# 7              0                  0         0.0
# 8              0                  0         0.0
# 9              0                  0         0.0
# 10             0                  0         0.0
# 11             0                  0         0.0
# 12             0                  0         0.0
# 13             0                  0         0.0

# %%
df3 = df.fillna(value=7)
df3
# Out:
#           jobs_id_list = ;"jobs_id_list = [{name John         job: eng  \
# 0                                         {name: Nate          job:eng
# 1                                         {name: Yuna         job: eng
# 2                                  {'name': 'Abraham'    'job': ""dr""
# 3                                    {'name': 'Brian'    'job': ""dr""
# 4                                    {'name': 'Janny'    'job': ""dr""
# 5                                     {'name': 'Nate'    'job': ""dr""
# 6                                     {'name': 'John'   'job': ""eng""
# 7                                                   ;                7
# 8                                                   ;                7
# 9                   {'name': 'Abraham', 'job': "dr...                7
# 10                  {'name': 'Brian', 'job': "dr",...                7
# 11                  {'name': 'Janny', 'job': "dr",...                7
# 12                  {'name': 'Nate', 'job': "dr", ...                7
# 13                  {'name': 'John', 'job': "eng",...                7
#
#          age: 35           id_n:76}  Unnamed: 4
# 0       'age: 50   'id_n':""None""}         7.0
# 1        age: 45           id_n:95}         7.0
# 2      'age': 27     'id_n':""89""}         7.0
# 3      'age': 30   'id_n':""None""}         7.0
# 4      'age': 39     'id_n':""67""}         7.0
# 5    'age': None     'id_n':""82""}         7.0
# 6    'age': None    'id_n':""69""}"         7.0
# 7              7                  7         7.0
# 8              7                  7         7.0
# 9              7                  7         7.0
# 10             7                  7         7.0
# 11             7                  7         7.0
# 12             7                  7         7.0
# 13             7                  7         7.0

# %%
df4 = df.fillna(method = 'pad')
df4
# Out:
#           jobs_id_list = ;"jobs_id_list = [{name John         job: eng  \
# 0                                         {name: Nate          job:eng
# 1                                         {name: Yuna         job: eng
# 2                                  {'name': 'Abraham'    'job': ""dr""
# 3                                    {'name': 'Brian'    'job': ""dr""
# 4                                    {'name': 'Janny'    'job': ""dr""
# 5                                     {'name': 'Nate'    'job': ""dr""
# 6                                     {'name': 'John'   'job': ""eng""
# 7                                                   ;   'job': ""eng""
# 8                                                   ;   'job': ""eng""
# 9                   {'name': 'Abraham', 'job': "dr...   'job': ""eng""
# 10                  {'name': 'Brian', 'job': "dr",...   'job': ""eng""
# 11                  {'name': 'Janny', 'job': "dr",...   'job': ""eng""
# 12                  {'name': 'Nate', 'job': "dr", ...   'job': ""eng""
# 13                  {'name': 'John', 'job': "eng",...   'job': ""eng""
#
#          age: 35           id_n:76}  Unnamed: 4
# 0       'age: 50   'id_n':""None""}         NaN
# 1        age: 45           id_n:95}         NaN
# 2      'age': 27     'id_n':""89""}         NaN
# 3      'age': 30   'id_n':""None""}         NaN
# 4      'age': 39     'id_n':""67""}         NaN
# 5    'age': None     'id_n':""82""}         NaN
# 6    'age': None    'id_n':""69""}"         NaN
# 7    'age': None    'id_n':""69""}"         NaN
# 8    'age': None    'id_n':""69""}"         NaN
# 9    'age': None    'id_n':""69""}"         NaN
# 10   'age': None    'id_n':""69""}"         NaN
# 11   'age': None    'id_n':""69""}"         NaN
# 12   'age': None    'id_n':""69""}"         NaN
# 13   'age': None    'id_n':""69""}"         NaN

# %%
df5 = df.fillna(method = 'bfill')
df5
# Out:
#           jobs_id_list = ;"jobs_id_list = [{name John         job: eng  \
# 0                                         {name: Nate          job:eng
# 1                                         {name: Yuna         job: eng
# 2                                  {'name': 'Abraham'    'job': ""dr""
# 3                                    {'name': 'Brian'    'job': ""dr""
# 4                                    {'name': 'Janny'    'job': ""dr""
# 5                                     {'name': 'Nate'    'job': ""dr""
# 6                                     {'name': 'John'   'job': ""eng""
# 7                                                   ;              NaN
# 8                                                   ;              NaN
# 9                   {'name': 'Abraham', 'job': "dr...              NaN
# 10                  {'name': 'Brian', 'job': "dr",...              NaN
# 11                  {'name': 'Janny', 'job': "dr",...              NaN
# 12                  {'name': 'Nate', 'job': "dr", ...              NaN
# 13                  {'name': 'John', 'job': "eng",...              NaN
#
#          age: 35           id_n:76}  Unnamed: 4
# 0       'age: 50   'id_n':""None""}         NaN
# 1        age: 45           id_n:95}         NaN
# 2      'age': 27     'id_n':""89""}         NaN
# 3      'age': 30   'id_n':""None""}         NaN
# 4      'age': 39     'id_n':""67""}         NaN
# 5    'age': None     'id_n':""82""}         NaN
# 6    'age': None    'id_n':""69""}"         NaN
# 7            NaN                NaN         NaN
# 8            NaN                NaN         NaN
# 9            NaN                NaN         NaN
# 10           NaN                NaN         NaN
# 11           NaN                NaN         NaN
# 12           NaN                NaN         NaN
# 13           NaN                NaN         NaN

# %%
df[["price"]] = df[["price"]].astype("object")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 df[["price"]] = df[["price"]].astype("object")
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
#    5785 if isinstance(key, Index):
#    5786     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5842, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5840     if use_interval_msg:
#    5841         key = list(key)
# -> 5842     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5844 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    5845 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['price'], dtype='object')] are in the [columns]"

# %%
df.dtypes

# %%
df["price"]=df["price"].astype(object, copy=True)

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
plt.pyplot.hist(df["price"])

# set x/y labels and plot title
plt.pyplot.xlabel("price")
plt.pyplot.ylabel("balcony")
plt.pyplot.title("price")
